# %% [markdown]
# <a href="https://colab.research.google.com/github/thumindu007/python-projs/blob/main/castle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to castle")



from codecraft import Game, Position
game = Game()
materials = game.materials
#break the floor###########################################################
p = Position(-10, 0, -10)
game.set_block(p, 1)
game.set_block(p, 0)
#build the wallll###########################################################
y = 1
for counter in range(0,12):
	p = Position(0, 1, y)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(0, 2, y)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(y, 1, 0)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(y, 2, 0)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(12, 1, y)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(12, 2, y)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(y, 1, 12)
	game.set_block(p, 1)
	y = y + 1
y = 1
for counter in range(0,12):
	p = Position(y, 2, 12)
	game.set_block(p, 1)
	y = y + 1
y = 1
# castle ############################################################################3

for counter in range(0,4):
	p = Position(6,y,6)
	game.set_block(p, 1)
	y = y + 1

y = 4
for counter in range(0,5):
	p = Position(4,1,y)
	game.set_block(p, 1)
	y = y + 1
y = 4
for counter in range(0,5):
	p = Position(4,2,y)
	game.set_block(p, 1)
	y = y + 1

y = 4
for counter in range(0,5):
	p = Position(y,1,4)
	game.set_block(p, 1)
	y = y + 1
y = 4
for counter in range(0,5):
	p = Position(y,2,4)
	game.set_block(p, 1)
	y = y + 1

y = 4
for counter in range(0,5):
	p = Position(y,1,8)
	game.set_block(p, 1)
	y = y + 1
y = 4
for counter in range(0,5):
	p = Position(y,2,8)
	game.set_block(p, 1)
	y = y + 1


y = 4
for counter in range(0,4):
	p = Position(8,1,y)
	game.set_block(p, 1)
	y = y + 1
y = 4
for counter in range(0,4):
	p = Position(8,2,y)
	game.set_block(p, 1)
	y = y + 1
    
p = Position(4,3,4)
game.set_block(p, 1)
p = Position(4,3,6)
game.set_block(p, 1)
p = Position(4,3,8)
game.set_block(p, 1)
p = Position(6,3,4)
game.set_block(p, 1)
p = Position(8,3,4)
game.set_block(p, 1)
p = Position(6,3,8)
game.set_block(p, 1)
p = Position(8,3,8)
game.set_block(p, 1)
p = Position(8,3,6)
game.set_block(p, 1)
