# %% [markdown]
# <a href="https://colab.research.google.com/github/thumindu007/python-projs/blob/main/olympic_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7655 sha256=d9c66f3081371ceada78b111e2ea072b6372f3816adb030358a4b7ba561b2042
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *
initializeTurtle()

penup()
speed(13)
left(90)
forward(400)
right(90)
pendown()

def draw_circle():
  for counter in range(1,180):
        forward(2)
        right(2)

def draw_circle_half_down():
  for counter in range(1,90):
        forward(2)
        left(2)

def draw_circle_half_left():
  for counter in range(1,90):
        forward(2)
        right(2)

def draw_circle_half_small():
  for counter in range(1,90):
        forward(1)
        right(2)

draw_circle()

penup()
right(90)
forward(130)
right(90)
forward(50)
right(180)
pendown()

forward(100)

penup()
right(180)
forward(50)
left(90)
forward(30)
right(90)
pendown()

draw_circle_half_down()

right(180)
forward(200)
penup()
right(180)
forward(150)
right(90)
forward(30)
left(90)
pendown()

draw_circle_half_up()
right(180)
draw_circle_half_up()

penup()
left(90)
forward(30)
left(90)
pendown()
forward(50)
right(180)
forward(200)
right(180)
forward(200)
right(90)

draw_circle_half_small()

penup()
right(90)
forward(50)
right(90)
forward(80)
pendown()

right(90)
forward(50)
penup()

left(90)
forward(80)
right(180)
pendown()

draw_circle_half_small()

hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
