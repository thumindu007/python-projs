# %% [markdown]
# <a href="https://colab.research.google.com/github/thumindu007/python-projs/blob/main/bycicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7655 sha256=56acc8eed02aa09162afc43eef1cc9428dd1a9255e6bb872d5f6541d42e6b4f6
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *
initializeTurtle()
speed(13)

def handle():
  for counter in range(1,60):
    forward(1)
    right(3)

def tier():
  for i in range(1,180):
    forward(1)
    right(2)
  for counter in range(1,5):
    for i in range(1,22):
      penup()
      forward(1)
      right(2)
      pendown()
    right(90)
    forward(60)
    right(90)

tier()

right(90)
penup()
forward(30)
right(90)
forward(30)
pendown()
left(25)
forward(100)
right(125)
forward(50)

handle()

penup()

left(45)
forward(20)
pendown()
left(8)
forward(80)
right(120)
forward(80)
right(120)
forward(80)
right(120)
penup()
forward(80)
right(60)
pendown()
forward(80)
penup()
forward(60)
pendown()
right(90)


tier()

penup()
for counter in range(1,9):
    for i in range(1,22):
      forward(1)
      right(2)

pendown()
left(100)
forward(68)

left(70)
forward(45)
left(60)
forward(15)
hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
